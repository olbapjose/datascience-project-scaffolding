# %%
# Ensure mypackage has been installed in the cluster or inside the virtual env where you are running this notebook

import os

carpeta_padre_donde_esta_my_package = "."  # poner la ruta adecuada

os.chdir(carpeta_padre_donde_esta_my_package)  # borrar esta línea si el wheel del paquete ha sido instalado.

from my_package.jobs import main_job

main_job.main("eda", "../config/project_config.json")
# Out:
# Llamando al EDA
